# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('dataset_Facebook.csv', sep=';')
df
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
df.describe()
# Out:
#        Page total likes    Category  Post Month  Post Weekday   Post Hour  \
# count        500.000000  500.000000  500.000000    500.000000  500.000000
# mean      123194.176000    1.880000    7.038000      4.150000    7.840000
# std        16272.813214    0.852675    3.307936      2.030701    4.368589
# min        81370.000000    1.000000    1.000000      1.000000    1.000000
# 25%       112676.000000    1.000000    4.000000      2.000000    3.000000
# 50%       129600.000000    2.000000    7.000000      4.000000    9.000000
# 75%       136393.000000    3.000000   10.000000      6.000000   11.000000
# max       139441.000000    3.000000   12.000000      7.000000   23.000000
#
#              Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# count  499.000000                  500.00000                     5.000000e+02
# mean     0.278557                13903.36000                     2.958595e+04
# ...

# %% [markdown]
# Creating Subset

# %%
df1=df[['Page total likes','Category','Post Month','Post Weekday']].loc[0:16]

# %%
df2=df[['Page total likes','Category','Post Month','Post Weekday']].loc[16:32]

# %%
df3=df[['Page total likes','Category','Post Month','Post Weekday']].loc[32:48]

# %%
df1
# Out:
#     Page total likes  Category  Post Month  Post Weekday
# 0             139441         2          12             4
# 1             139441         2          12             3
# 2             139441         3          12             3
# 3             139441         2          12             2
# 4             139441         2          12             2
# 5             139441         2          12             1
# 6             139441         3          12             1
# 7             139441         3          12             7
# 8             139441         2          12             7
# 9             139441         3          12             6
# 10            139441         2          12             5
# 11            139441         2          12             5
# 12            139441         2          12             5
# 13            139441         2          12             5
# 14            138414         2          12             4
# ...

# %%
df2
# Out:
#     Page total likes  Category  Post Month  Post Weekday
# 16            138414         3          12             3
# 17            138414         1          12             2
# 18            138414         3          12             2
# 19            138414         3          12             1
# 20            138414         2          12             1
# 21            138414         1          12             7
# 22            138414         1          12             7
# 23            138414         3          12             7
# 24            138414         2          12             6
# 25            138458         2          12             6
# 26            138458         2          12             5
# 27            138458         3          12             5
# 28            138895         2          12             5
# 29            138895         1          12             4
# 30            138895         2          12             4
# ...

# %%
df3
# Out:
#     Page total likes  Category  Post Month  Post Weekday
# 32            138895         3          12             3
# 33            138895         3          12             2
# 34            138895         1          12             2
# 35            138895         2          12             1
# 36            138895         3          12             1
# 37            138895         1          12             7
# 38            138895         2          12             7
# 39            138895         1          12             7
# 40            138895         2          12             6
# 41            138895         1          12             6
# 42            138353         1          12             5
# 43            138353         1          12             5
# 44            138353         1          12             4
# 45            138353         1          12             4
# 46            138353         1          12             3
# ...

# %% [markdown]
# Merging data

# %%
merge = pd.concat([df1,df2,df3])

# %%
merge
# Out:
#     Page total likes  Category  Post Month  Post Weekday
# 0             139441         2          12             4
# 1             139441         2          12             3
# 2             139441         3          12             3
# 3             139441         2          12             2
# 4             139441         2          12             2
# 5             139441         2          12             1
# 6             139441         3          12             1
# 7             139441         3          12             7
# 8             139441         2          12             7
# 9             139441         3          12             6
# 10            139441         2          12             5
# 11            139441         2          12             5
# 12            139441         2          12             5
# 13            139441         2          12             5
# 14            138414         2          12             4
# ...

# %% [markdown]
# Sort Data

# %%
Sorting = merge.sort_values('Page total likes',ascending=False)

# %%
Sorting
# Out:
#     Page total likes  Category  Post Month  Post Weekday
# 0             139441         2          12             4
# 8             139441         2          12             7
# 1             139441         2          12             3
# 13            139441         2          12             5
# 12            139441         2          12             5
# 11            139441         2          12             5
# 9             139441         3          12             6
# 10            139441         2          12             5
# 7             139441         3          12             7
# 6             139441         3          12             1
# 5             139441         2          12             1
# 4             139441         2          12             2
# 3             139441         2          12             2
# 2             139441         3          12             3
# 34            138895         1          12             2
# ...

# %% [markdown]
# Transposing the data

# %%
transpose = merge.transpose()
transpose
# Out:
#                       0       1       2       3       4       5       6   \
# Page total likes  139441  139441  139441  139441  139441  139441  139441
# Category               2       2       3       2       2       2       3
# Post Month            12      12      12      12      12      12      12
# Post Weekday           4       3       3       2       2       1       1
#
#                       7       8       9   ...      39      40      41      42  \
# Page total likes  139441  139441  139441  ...  138895  138895  138895  138353
# Category               3       2       3  ...       1       2       1       1
# Post Month            12      12      12  ...      12      12      12      12
# Post Weekday           7       7       6  ...       7       6       6       5
#
#                       43      44      45      46      47      48
# Page total likes  138353  138353  138353  138353  138353  138353
# Category               1       1       1       1       1       1
# ...

# %%
merge.shape
# Out:
# (51, 4)

# %%
Reshape = pd.pivot_table(df,index=["Type","Category"])
Reshape
# Out:
#                  Lifetime Engaged Users  \
# Type   Category
# Link   1                     357.850000
#        2                     103.000000
#        3                     282.000000
# Photo  1                     852.227027
#        2                     727.208791
#        3                     833.553333
# Status 1                    2074.666667
#        2                    2150.210526
#        3                     969.500000
# Video  1                    1707.000000
#
#                  Lifetime People who have liked your Page and engaged with your post  \
# Type   Category
# Link   1                                                214.050000
#        2                                                 92.000000
#        3                                                259.000000
# Photo  1                                                522.508108
#        2                                                446.604396
# ...
